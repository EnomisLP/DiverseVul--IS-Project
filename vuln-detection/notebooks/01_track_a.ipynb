# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01 — Track A: Classical Machine Learning Baselines"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from src.utils import load_config, set_seed\n",
    "from src.data import load_rdiversevul, load_holdout_split\n",
    "from src.track_a.train import run_all_track_a\n",
    "\n",
    "cfg_a = load_config('configs/track_a.yaml')\n",
    "set_seed(cfg_a.cv.random_state)\n",
    "\n",
    "df = load_rdiversevul(data_dir='data/raw')\n",
    "train_idx, _ = load_holdout_split()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "results = run_all_track_a(\n",
    "    cfg=cfg_a,\n",
    "    df=df,\n",
    "    train_idx=train_idx,\n",
    "    overwrite=True\n",
    ")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": { "display_name": "Python 3", "language": "python", "name": "python3" },
  "language_info": { "name": "python", "version": "3.10.0" }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
